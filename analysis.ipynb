# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("arduino_float_data.csv")

# %%
df
# Out:
#      X (g)  Y (g)  Z (g)
# 0    -0.89  -0.00   0.23
# 1    -0.88   0.00   0.23
# 2    -0.89  -0.00   0.24
# 3    -0.90  -0.07   0.23
# 4    -0.88  -0.04   0.20
# ..     ...    ...    ...
# 569  -0.90   0.09   0.22
# 570  -0.90   0.02   0.16
# 571  -0.90   0.09   0.15
# 572  -0.90   0.03   0.20
# 573  -0.90   0.09   0.07
#
# [574 rows x 3 columns]

# %%
df.rename(columns={'X (g)':'Acc_x', 'Y (g)':'Acc_y', 'Z (g)':'Acc_z'}, inplace=True)

# %%
plt.plot(df[["Acc_x"]], label='Acc_x')
plt.plot(df[["Acc_y"]], label='Acc_y')
plt.plot(df[["Acc_z"]], label='Acc_z')
plt.legend(loc='best')

# %%
df['Module'] = np.sqrt(df['Acc_x']**2 + df['Acc_y']**2 + df['Acc_z']**2)
plt.plot(df[["Module"]], label='Module')
plt.legend()
